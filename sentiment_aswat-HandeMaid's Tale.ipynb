# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:\\Users\\Aswathi\\Desktop\\Handmaids tale hulu location.xlsx",
                   sheet_name = 'Edges',skiprows=0,header=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9193 entries, 0 to 9192
# Data columns (total 56 columns):
# Vertex 1                          9193 non-null object
# Vertex 2                          9193 non-null object
# Color                             0 non-null float64
# Width                             0 non-null float64
# Style                             0 non-null float64
# Opacity                           0 non-null float64
# Visibility                        0 non-null float64
# Label                             0 non-null float64
# Label Text Color                  0 non-null float64
# Label Font Size                   0 non-null float64
# Reciprocated?                     8785 non-null object
# ID                                8785 non-null float64
# Dynamic Filter                    0 non-null float64
# Add Your Own Columns Here         0 non-null float64
# Relationship                      9193 non-null object
# Relationship Date (UTC)           8785 non-null datetime64[ns]
# Tweet                             8785 non-null object
# URLs in Tweet                     3525 non-null object
# Domains in Tweet                  3525 non-null object
# Hashtags in Tweet                 2241 non-null object
# Media in Tweet                    1404 non-null object
# Tweet Image File                  8785 non-null object
# Tweet Date (UTC)                  8785 non-null datetime64[ns]
# Twitter Page for Tweet            8785 non-null object
# Latitude                          1 non-null float64
# Longitude                         1 non-null float64
# Imported ID                       8785 non-null float64
# In-Reply-To Tweet ID              480 non-null float64
# Favorited                         8785 non-null float64
# Favorite Count                    8785 non-null float64
# In-Reply-To User ID               538 non-null float64
# Is Quote Status                   8785 non-null float64
# Language                          8785 non-null object
# Possibly Sensitive                0 non-null float64
# Quoted Status ID                  62 non-null float64
# Retweeted                         8785 non-null float64
# Retweet Count                     8785 non-null float64
# Retweet ID                        3891 non-null float64
# Source                            8785 non-null object
# Truncated                         8785 non-null float64
# Unified Twitter ID                8785 non-null float64
# Imported Tweet Type               8785 non-null object
# Added By Extended Analysis        8785 non-null float64
# Corrected By Extended Analysis    8785 non-null float64
# Place Bounding Box                248 non-null object
# Place Country                     248 non-null object
# Place Country Code                248 non-null object
# Place Full Name                   248 non-null object
# Place ID                          248 non-null object
# Place Name                        248 non-null object
# Place Type                        248 non-null object
# Place URL                         248 non-null object
# Edge Weight                       9193 non-null int64
# Vertex 1 Group                    9193 non-null int64
# Vertex 2 Group                    9193 non-null int64
# Shared Content                    408 non-null float64
# dtypes: datetime64[ns](2), float64(29), int64(3), object(22)
# memory usage: 3.9+ MB

# %%
df = df[['Place Country Code','Place Full Name','Tweet']]

# %%
df.sample(5)
# Out:
#      Place Country Code Place Full Name  \
# 2870                NaN             NaN
# 4940                NaN             NaN
# 6885                NaN             NaN
# 533                 NaN             NaN
# 5657                 US     Oakland, CA
#
#                                                   Tweet
# 2870  This 'Handmaid's Tale' moment featuring '#Frie...
# 4940  RT @katebushnews: Kate's 'This Woman's Work' w...
# 6885  Finalmente è tornato #TheHandmaidsTale, con un...
# 533   Can Hulu keep 'The Handmaid's Tale' momentum g...
# 5657  I just watched the first episode of the handma...

# %%
df[['City','state']] = df['Place Full Name'].str.split(',',n =1,expand=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9193 entries, 0 to 9192
# Data columns (total 5 columns):
# Place Country Code    248 non-null object
# Place Full Name       248 non-null object
# Tweet                 8785 non-null object
# City                  248 non-null object
# state                 247 non-null object
# dtypes: object(5)
# memory usage: 359.2+ KB

# %%
df.sample(7)
# Out:
#      Place Country Code Place Full Name  \
# 3825                NaN             NaN
# 661                 NaN             NaN
# 192                 NaN             NaN
# 7301                NaN             NaN
# 708                 NaN             NaN
# 4472                NaN             NaN
# 3633                NaN             NaN
#
#                                                   Tweet City state
# 3825  OS 10 PRIMEIROS MINUTOS DA S2 DE THE HANDMAIDS...  NaN   NaN
# 661   So excited to start season 2 of The Handmaids ...  NaN   NaN
# 192   Hulu is being fake as hell right now. I’m just...  NaN   NaN
# 7301  RT @HandmaidsOnHulu: Take the future into your...  NaN   NaN
# 708   Five Boston references in "The Handmaid’s Tale...  NaN   NaN
# 4472  RT @kann_brooks: Let @LEBassett and @emmaladyr...  NaN   NaN
# 3633  RT @ilovelucius: Who you gotta fuck to watch t...  NaN   NaN

# %%
df.drop('Place Full Name', axis = 1, inplace=True)

# %%
df.columns = ['Country','Tweet','City','State']

# %%
df = df[df['Tweet'].isnull()==False]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8785 entries, 0 to 8784
# Data columns (total 4 columns):
# Country    248 non-null object
# Tweet      8785 non-null object
# City       248 non-null object
# State      247 non-null object
# dtypes: object(4)
# memory usage: 343.2+ KB

# %% [markdown]
# ## Cleaning the tweets to remove
# 1. URL links
# 2. HTML tags
# 3. Numbers
# 4. Hashtags and Mentions(@)
# 5. Emoticons

# %%
import re
import csv
from textblob import TextBlob
from bs4 import BeautifulSoup
from tweepy import OAuthHandler
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aswathi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()

# %%
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))

def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', text)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)# creates unnecessary white spaces
    lower_case = letters_only.lower()
    words = tok.tokenize(lower_case) #tokenize and join together to remove unneccessary white spaces
    return (" ".join(words)).strip()

# %%
testing = df.Tweet[:10]
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ['the handmaid s tale returns today and it s still one of the best shows to ever grace the screen blessed be the fruit s review of season two',
#  'for fans of who are starting season check out our most heartbreaking moments from season hulu handmaidstaleseason handmaidstale handmaidsonhulu',
#  'con esta tem tica tan incre ble y a la vez tan pr xima por c mo en muchas cosas no difiere mucho de la realidad actual se convierte en un imprescindible as habla de the handmaid s tale a horas del estreno de la temporada',
#  'the handmaid s tale awteam abod a',
#  'the handmaid s tale awteam abod a',
#  'with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'the handmaid s tale season review moss grows only more virtuosic as the rancid layers of this terrifying new society are revealed',
#  'socoroooo como assim vai sair a segunda temporada de the handmaids tale hoje',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready']

# %%
len(df.Tweet)
# Out:
# 8785

# %%
df['Tweet'][8786]
# Out:
# nan

# %%
df[df['Tweet'].isnull()]
# Out:
#      Country Tweet City State
# 8785     NaN   NaN  NaN   NaN
# 8786     NaN   NaN  NaN   NaN
# 8787     NaN   NaN  NaN   NaN
# 8788     NaN   NaN  NaN   NaN
# 8789     NaN   NaN  NaN   NaN
# 8790     NaN   NaN  NaN   NaN
# 8791     NaN   NaN  NaN   NaN
# 8792     NaN   NaN  NaN   NaN
# 8793     NaN   NaN  NaN   NaN
# 8794     NaN   NaN  NaN   NaN
# 8795     NaN   NaN  NaN   NaN
# 8796     NaN   NaN  NaN   NaN
# 8797     NaN   NaN  NaN   NaN
# 8798     NaN   NaN  NaN   NaN
# 8799     NaN   NaN  NaN   NaN
# 8800     NaN   NaN  NaN   NaN
# 8801     NaN   NaN  NaN   NaN
# 8802     NaN   NaN  NaN   NaN
# 8803     NaN   NaN  NaN   NaN
# 8804     NaN   NaN  NaN   NaN
# 8805     NaN   NaN  NaN   NaN
# 8806     NaN   NaN  NaN   NaN
# 8807     NaN   NaN  NaN   NaN
# 8808     NaN   NaN  NaN   NaN
# 8809     NaN   NaN  NaN   NaN
# 8810     NaN   NaN  NaN   NaN
# 8811     NaN   NaN  NaN   NaN
# 8812     NaN   NaN  NaN   NaN
# 8813     NaN   NaN  NaN   NaN
# 8814     NaN   NaN  NaN   NaN
# ...      ...   ...  ...   ...
# 9163     NaN   NaN  NaN   NaN
# 9164     NaN   NaN  NaN   NaN
# 9165     NaN   NaN  NaN   NaN
# 9166     NaN   NaN  NaN   NaN
# 9167     NaN   NaN  NaN   NaN
# 9168     NaN   NaN  NaN   NaN
# 9169     NaN   NaN  NaN   NaN
# 9170     NaN   NaN  NaN   NaN
# 9171     NaN   NaN  NaN   NaN
# 9172     NaN   NaN  NaN   NaN
# 9173     NaN   NaN  NaN   NaN
# 9174     NaN   NaN  NaN   NaN
# 9175     NaN   NaN  NaN   NaN
# 9176     NaN   NaN  NaN   NaN
# 9177     NaN   NaN  NaN   NaN
# 9178     NaN   NaN  NaN   NaN
# 9179     NaN   NaN  NaN   NaN
# 9180     NaN   NaN  NaN   NaN
# 9181     NaN   NaN  NaN   NaN
# 9182     NaN   NaN  NaN   NaN
# 9183     NaN   NaN  NaN   NaN
# 9184     NaN   NaN  NaN   NaN
# 9185     NaN   NaN  NaN   NaN
# 9186     NaN   NaN  NaN   NaN
# 9187     NaN   NaN  NaN   NaN
# 9188     NaN   NaN  NaN   NaN
# 9189     NaN   NaN  NaN   NaN
# 9190     NaN   NaN  NaN   NaN
# 9191     NaN   NaN  NaN   NaN
# 9192     NaN   NaN  NaN   NaN
#
# [408 rows x 4 columns]

# %%
# %%time
print("Cleaning and parsing the tweets...\n")
clean_tweet = []
for i in range(0,len(df.Tweet)):  
    #print(i)
    #print(df['Tweet'][i])
    clean_tweet.append(tweet_cleaner(df['Tweet'][i]))
# Out:
# Cleaning and parsing the tweets...
#
# Wall time: 2.57 s

# %%
clean_tweet
# Out:
# ['the handmaid s tale returns today and it s still one of the best shows to ever grace the screen blessed be the fruit s review of season two',
#  'for fans of who are starting season check out our most heartbreaking moments from season hulu handmaidstaleseason handmaidstale handmaidsonhulu',
#  'con esta tem tica tan incre ble y a la vez tan pr xima por c mo en muchas cosas no difiere mucho de la realidad actual se convierte en un imprescindible as habla de the handmaid s tale a horas del estreno de la temporada',
#  'the handmaid s tale awteam abod a',
#  'the handmaid s tale awteam abod a',
#  'with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'the handmaid s tale season review moss grows only more virtuosic as the rancid layers of this terrifying new society are revealed',
#  'socoroooo como assim vai sair a segunda temporada de the handmaids tale hoje',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'screams to no one in particular the handmaids tale is back',
#  'westworld is back a new season of the handmaids tale released too all in time for me to ignore my finals',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'handmaids tale is back it s lit',
#  'the handmaids tale is back y all',
#  'handmaids tale has dropped leave me alone handmaidstale',
#  'rt quero todos os equerdomachos nerds punheteiros desse pa s traduzindo the handmaids tale pra mulherada ainda hoje vai rapido qu',
#  'i finished the first episodes of the handmaids tale and season already has me shook resistsister',
#  'handmaids tale season is already breaking my heart',
#  'handmaids tale season premier noooooope holy shit no ten minutes in and i am shooketh',
#  'rt gonna watch the new season of handmaids tale cuz i need something scarier to distract me from this kanye mess',
#  'no encuentro subt tulo para the handmaids tale',
#  'season of the handmaids tale is intense and absolutely heartbreaking queer friends episode will be hard to watch',
#  'brand new tv show the handmaid s tale is starting today tune in to hulu and watch first episode in hours',
#  'i am not happy that i have to wait a week to see a new episode of the handmaids tale',
#  'in celebration of s and not letting the bastards get us down i m shamelessly resharing my first piece for back in oct',
#  'rt the group activated hangings the tearing apart of human beings the forced childbearing and the appropriation of the results',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt thehandmaidstale season which premieres today explores the dark side of freedom our review',
#  'handmaids tale and ice cream seems pretty okay with me',
#  'season of the handmaids tale is on yessssss',
#  'the fenway park scene in the handmaids tale premiere made me physically ill',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt five boston references in the handmaid s tale that make it a little too real',
#  'bibliomarket the handmaids tale season episodes and',
#  'handmaid amp x s tale season teaser elisabeth moss is done being miss nice girl',
#  'omg season two of a handmaids tale is on hulu',
#  'rt omg season two of a handmaids tale is on hulu',
#  'today started off so stressful but i got back on track and i m getting all my shit done and now i m warm and happy and watching the handmaids tale and wow i love',
#  'omg so excited the new episodes of the handmaids tale is now on hulu bingehandmaidstale',
#  'but seriously handmaids tale is clutch y all should be watching it',
#  'fuck the handmaids tale that opening shit was too brutal amp triggering af',
#  'handmaids tale timeeer',
#  'vou assistir os eps de handmaids tale que j sa ram nesse fds eu to mt sedenta pela segunda temporada da s rie do mil nio',
#  'handmaids tale is back',
#  'handmaids tale makes me want to apply for dual citizenship outside of the us like omg',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'criando coragem pra ver a season de the handmaids tale ainda n o superei a season finale da primeira temporada',
#  'saiu nova temp de the handmaids tale meu deis eu nao tava preparada pra isso vo ter que cancelar tds os roles',
#  'i have never been a major reader but i did read ht when it came out these quotes are the reason why nolite te bastardes carborundorum via',
#  'a netflix deve querer morrer por n o ter aceitado produzir the handmaids tale',
#  'rt quero todos os equerdomachos nerds punheteiros desse pa s traduzindo the handmaids tale pra mulherada ainda hoje vai rapido qu',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the handmaids tale is back today i almost forgot',
#  'just watched the two new episodes of handmaids tale wow its sooo good glad to see back she was incredible way to go and of course is amazing',
#  'just watched the two new episodes of handmaids tale wow its sooo good glad to see back she was incredible way to go and of course is amazing',
#  'me acabo de enterar que ma ana sale the handmaids tale aaaahahhaaaaha',
#  'rt the handmaid s tale returns for season on wednesday here s s review',
#  'rt the handmaid s tale returns for season on wednesday here s s review',
#  'season two handmaids tale',
#  'rt everything about the handmaid s tale s second season is bigger the vox culture team s review of episode one',
#  'very exciting to see the completionist on this list of books for fans of handmaidstale season tonight living for it',
#  'bout to drink some tequila and get to bingin on the handmaids tale season selfcarekinda',
#  'girl handmaids tale is back too if you haven t watched it yet i think you should bc we enjoy the same things and it s inteeense',
#  'the handmaids tale is fucked up',
#  'the women of gilead rise up in the handmaid s tale s second season',
#  'the handmaids tale x',
#  'the handmaids tale is so good wow',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'handmaids tale and westworld s are out now but im going to wait till the season ends',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'they did not choose this song for this scene minutes into handmaids tale holy hell idk if i can do this',
#  'alouuuuu the handmaids tale pega leve porra',
#  'the handmaids tale is back on yall',
#  'no pude ver mas de los primeros minutos del nuevo capitulo de the handmaids tale',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'minutes into handmaids tale season and i m already shaking',
#  'my dad decided to watch the handmaids tale that hulu original one and it s interesting but it s so traumatic and shows such awful things being done to women that it s hard for me to watch',
#  'it s time season of the handmaids tale i so excited and anxious thehandmaidtale',
#  'j to me tremendo toda com esse retorno de the handmaids tale',
#  'the handmaids tale has to be the best show i ve ever seen',
#  'passando uma afli o fudida com the handmaids tale',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'when offred watches friends on handmaids tale and you just like',
#  'ahhh the handmaids tale ma ana tengo que gastarme cheles en hbo que en breves empieza westwold tambi n y ahhh',
#  'the handmaids tale',
#  'rt the group activated hangings the tearing apart of human beings the forced childbearing and the appropriation of the results',
#  'rt tudo que importa que essa semana volta the handmaids tale',
#  'are you stressed out from the handmaid s tale s season premiere add to it with our recap of the new episode june',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far',
#  'thats some handmaids tale shit right there',
#  'thats some handmaids tale shit right there',
#  'the handmaids tale has been ok for minutes and they already got me all the way fucked up',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the handmaids tale is back',
#  'peaky blinders a handmaids tale or west world what s a girl to do',
#  'handmaids tale babyyyyyy',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt elisabeth moss on standing up for her fellow actors during thehandmaidstale season it s my responsibility i always en',
#  'i found that while i watch the handmaids tale i have hope for her to escape and the world to right itself that s what reminds me that i should hold on to hope for our own reality even if hope seems fleeting',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'if yall arent watching the handmaids tale idk what you re waiting for',
#  'i need to rewatch season also and if any of y all haven t seen the handmaids tale yet what s wrong with u go fix that immediately',
#  'delon wright looks like that girl from orange is the new black and handmaids tale',
#  'handmaids tale is the hardest thing to watch',
#  'rt the handmaid s tale volta mais sombria em temporada produtor compara s rie ao governo trump g https',
#  'with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'mb got home late then we got to talking so my handmaids tale evening is running way late on my way to get snacks and my show on lol',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'new season of the handmaids tale is so weird',
#  'margaret atwood on how she came to write the handmaid s tale via',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'british fans vent frustration over the handmaid s tale wait',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far indie',
#  'i m watching the new season of handmaids tale and ahhhhhhhhhhhhhhhhhhh',
#  'things to know before watching the handmaid s tale season',
#  'you all need to see the handmaids tale it s so freaking good',
#  'the handmaids tale is back much excite',
#  'the number of ways i would ve already killed myself in handmaids tale environment',
#  'cade a legenda de the handmaids tale eu to chorosa',
#  'handmaids tale',
#  'this first episode of handmaids tale is really hard to stomach',
#  'omg handmaids tale is back blessed be the fucken fruit baby',
#  'ja tem legenda de handmaids tale',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'amem the handmaids tale',
#  'rt season of handmaidstale was written and filmed entirely during the trump presidency its influence is felt throughout https',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'why the heck do they have handmaids tale episode amp on spotify',
#  'holy motherforking shirtballs s e of handmaids tale hulu why on earth would you send us into desperate forking housewives instead of s e',
#  'they are not playing woman s work on handmaids tale',
#  'i d like to think that i d be like june in the handmaids tale but we all know i d be like ofwarren',
#  'i watched the first two episodes of the second season of the handmaids tale and im like ehhhhhhhhhhhhhhh i do like the backstory with emily ofglen tho shes probably my favorite character',
#  'when asked whether the handmaid s tale is about to come true i remind myself that there are two futures in the book and that if the first one comes true the second one may do so also via',
#  'rt nick from the handmaids tale is my ryan gosling',
#  'rt nick from the handmaids tale is my ryan gosling',
#  'watching the new season of the handmaids tale so good',
#  'holy shit i guess i accidentally started playing a random spotify playlist while watching handmaids and the fairytale theme from shrek started playing and for like whole seconds i was like wow they really used this song in handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the new season of the handmaids tale came out today so get excited for me tweeting up a feminist storm again over the next few weeks while new episodes are released',
#  'the handmaids tale is off to a great start',
#  'what scene from season two premiere episode june made you cringe the most handmaidstale handmaidstaleseason',
#  'what scene from season two premiere episode june made you cringe the most handmaidstale handmaidstaleseason',
#  'hoje voltou the handmaids tale fode essa buceta',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'new episodes of the handmaids tale are out everyone go watch',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'oh my goodness the handmaids tale new season is frightening i can t believe it',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'hulu is being fake as hell right now i m just trying to watch handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'she s already given away a child or had a child taken away from her in season and here she is in season pregnant and she s about to have another child that s being taken away the handmaid s tale tackles motherhood in season',
#  'rt she s already given away a child or had a child taken away from her in season and here she is in season pregnant and she',
#  'rt thehandsmaidstale is too much like real life',
#  'rt i talked to alexis bledel about her deeply horrifying thehandmaidstale storyline and the scene that upset me so much that i',
#  'a potential mass murder scene at fenway for the return of the handmaids tale is fucked up hollywood needs to stop filming in boston now notcool itsourfuckingcity thehandsmaidstale fenway',
#  'yassss handmaids tale so ready for this',
#  'handmaids tale season',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'loving the new season of the handmaids tale so good',
#  'shhhhh a handmaids tale season is on',
#  'margaret atwood on how she came to write the handmaid s tale via',
#  'if you need me i ll be binge watching season two of the handmaids tale',
#  'friends breaking bad the handmaids tale big little lies etc etc',
#  'honestly i m always amazed by the performances of the actors in the handmaids tale but damn the extras really out there breaking my heart like idk you ladies but you killlllllin it',
#  'rt five boston references in the handmaid s tale that make it a little too real',
#  'rt ann dowd i think it s a reminder in a wonderful way for people to stay alert stay awake keep thinking on your own and not t',
#  'rt already losing my mind over handmaids tale season',
#  'rt margaret atwood on how she came to write the handmaid s tale',
#  'rt margaret atwood on how she came to write the handmaid s tale',
#  'praise be handmaids tale is back',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far',
#  'finally the handmaids tale is back',
#  'rt five boston references in the handmaid s tale that make it a little too real',
#  'streaming su timvision la seconda stagione di the handmaid s tale in contemporanea con gli usa',
#  'rt perguntas que queremos respostas na segunda temporada de the handmaid s tale',
#  'empieza la segunda temporada de the handmaids tale y',
#  'i hope this season of handmaids tale gets better i m kinda underwhelmed by the premiere',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'i m confused why is there only two episodes of the second season of the handmaids tale',
#  'le di play a the handmaids tale y con el review de la temporada pasada ya se me cruz la piel estoy a esto de largarme a llorar',
#  'rt aqu teniu la meva cr tica de la temporada de the handmaid s tale basada en els dos primers episodis',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'yeoooow handmaids tale is guts',
#  'starting season of the handmaids tale',
#  'holllllyyyyy handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'so hulu doesn t give you the entire second season of the handmaids tale all at once why the fuck did i binge watch season one',
#  'radical feminists think handmaids tale is a documentary',
#  'scarred from that first scene on the new season of handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'i watched the first episode of season of the handmaids tale and i don t want to watch the rest they wrapped up the show i would be content with this being the end margaret atwood would be proud i mean it would be too happy of an ending for her but still',
#  'rt tv the handmaids tale p',
#  'the handmaids tale is so scary i am a scared girl rn',
#  'handmaids tale is too realistic to be enjoyable',
#  'wow season of handmaids tale literally had me sobbing within the first minutes',
#  'turns out handmaids tale is even darker season',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt season of handmaidstale was written and filmed entirely during the trump presidency its influence is felt throughout https',
#  'handmaids tale is perfect',
#  'the handmaids tale exemplo de sororidade',
#  'feeling i have watching the gripping scary as hell handmaids tale feeling i have every morning and see the president has his phone back and has been watching fox and friends',
#  'my sister is watching the season premiere of the handmaids tale and i think she s dead she is just looking at the screen like she has seen a ghost i hope she s ok',
#  'auto response hello i will be out of the office with limited access to email as i will be binge watching handmaids tale praisebe',
#  'auto response hello i will be out of the office with limited access to email as i will be binge watching handmaids tale praisebe',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'i thought the whole season of handmaids tale was out',
#  'support ps i followed all the tips my internet connection is fine only buffering during handmaids tale tried watching three other shows no problem',
#  'handmaids tale season is out holy fuck',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt freedom comes at a cost season of the emmy and golden globe winning series the handmaidstale is now streaming o',
#  'handmaids tale makes me so mad',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'being able to only watch epsodies of handmaids tale season is the biggest tease',
#  'handmaids tale season what are you doing to me',
#  'et puis avez vous commenc la deuxi me saison',
#  'oxe the handmaids tale j voltou e eu nem me liguei',
#  'handmaids tale gives me such anxiety dear god the subtle ways they undermine women pre revolution is painful everything is just beyond',
#  'rt man kevin williamson must be watching this handmaids tale season opener like porn',
#  'rt season of handmaidstale was written and filmed entirely during the trump presidency its influence is felt throughout https',
#  'neeeeeeeeeed to watch season of handmaids tale asap',
#  'i watched the first season of the handmaids tale w my mom but now i ve moved out and idk if i can handle it alone',
#  'rt the group activated hangings the tearing apart of human beings the forced childbearing and the appropriation of the results',
#  'amazing start to the second season of handmaids tale',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far',
#  'me indica uma s rie scandal the handmaids tale htgawm law amp order svu jessica jones aaaaaaa sao tantas tops',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'gut instinct told me watching handmaids tale would be less disturbing than watching today s mets game',
#  'the handmaids tale makes me so stressed and want to cry',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'rt season of handmaidstale was written and filmed entirely during the trump presidency its influence is felt throughout https',
#  'why the handmaid s tale is more relevant one year after the first season jessica valenti',
#  'on writing thehandmaidstale',
#  'stop doing us dirty and just release the rest of the handmaids tale episodes i need to binge',
#  'vou assistir the handmaids tale esse meu momento',
#  'omg they released new episodes of handmaids tale brb freaking out',
#  'eu gritando pq aparece um dvd de friends em the handmaids tale socorrokkkkkkkkkk que dor no cora o',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'bruh the opening scene of the handmaids tale fuck',
#  'the handmaids tale takes netflix and chill to hulu and emotional breakdown',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'bom sem mais delongas quero torrent de handmaids tale na minha mesa pra hj ainda obrigarden',
#  'those last minutes of handmaids tale s e had me crying so much',
#  'season of the handmaid s tale now live on hulu',
#  'omg that handmaids tale is going to give me a heart attack',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'kanye is canceled again and the handmaids tale is back',
#  'eating a whole box of shaped mac amp cheese and watching handmaids tale like an adult',
#  'rt breaking down the harrowing opening minutes of the hulu s handmaidstale',
#  'offred might be an example for all of us',
#  'everything you need to know before the handmaid s tale season airs tonight',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'the handmaids tale',
#  'who else is watching handmaids tale tonight',
#  'handmaids tale is the best series on facts lol',
#  'lordy',
#  'a handmaids tale',
#  'wowowowowowowow handmaids tale season is out',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'psa first two episodes of season of handmaids tale is on hulu',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'a ultima cena de handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'why is the handmaids tale soooo good',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the handmaids tale is back',
#  'gente do ceu o ep da segunda temporada de the handmaids tale o que foi isso eu to sem palavras tipo meu deus',
#  'i can t believe asmwhwkshwks peguei um spoiler de handmaids tale aaaaaaaa',
#  'the handmaids tale makes me so angry i wanna cry i m not even said i m just so frustrated',
#  'rt the handmaid s tale season episode explores emily s gut wrenching back story',
#  'me and watching the handmaids tale',
#  'rt me and watching the handmaids tale',
#  'season of the handmaid s tale now live on hulu',
#  'rt the handmaid s tale season episode explores emily s gut wrenching back story',
#  'rt the handmaid s tale season episode explores emily s gut wrenching back story',
#  'omg handmaids tale is back im going to die',
#  'rt man kevin williamson must be watching this handmaids tale season opener like porn',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'i am purposely waiting for finals to be over before i start season of handmaids tale bcuz i will binge watch it uncontrollably',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'damn handmaids tale season episode has me all emotional i love how gritty it is',
#  'watch the handmaids tale or read the book this is why you can t be a part of government',
#  'watching handmaids tale and damn this show is fucked up i love it',
#  'season of the handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'raise your hand if you re not emotionally prepared enough for the new episodes of handmaids tale i ve waited for this moment but what have i done to prepare for this moment nothing',
#  'westworld',
#  'the handmaids tale praisebe',
#  'logs off twitter to watch handmaids tale logs on sean spicer book charlie rose tv show with just men who harass women more kanye bullshit cohen taking the fifth people still bitching about the state dinner rice',
#  'rt org some books haunt the reader others haunt the writer the handmaid s tale has done both via',
#  'rt org some books haunt the reader others haunt the writer the handmaid s tale has done both via',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'am i the only one who thought i was gonna get the binge handmaids tale to get disappointed by only two episodes',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'handmaids tale is out and i m freaking outtttt',
#  'i was thrilled to see you in the handmaids tale season episode was disappointed to see your character was a short timer',
#  'the handmaids tale season is on hulu laid ease goodbye im gonna binge watch for the next ten horis',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'dark ou the handmaids tale',
#  'rt handmaids tale season opening scene here we fucking go that was a way to start a season jaw on the ground heart sto',
#  'sem palavras com the handmaids tale',
#  'rt here s what critics are saying about the handmaid s tale season handmaidstale',
#  'rt here s what critics are saying about the handmaid s tale season handmaidstale',
#  'rt here s what critics are saying about the handmaid s tale season handmaidstale',
#  'i made a rule for myself i would not include anything that human beings had not already done in some other place or time',
#  'for fuck s sakes when am i supposed to watch the handmaids tale',
#  'me preparando psicologicamente para dar o play thehandmaidstale arrisca segunda temporada mais pesada que a primeira',
#  'elisabeth moss amp cast on shocking handmaid s tale s season opener season feels quaint via',
#  'can t wait to go home and watch the handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt blood red bonnets heavy metal and more proof that dystopian fashion doesn t mean drab',
#  'so ya esta the handmaids tale season en hulu y season de htgawm no se cu l ver primero',
#  'rt so i m recapping this season of the handmaid s tale for the new york times a warm welcome back to the most artfully agon',
#  'the handmaids tale continua sendo a s rie mais foda dos ltimos anos que fotografia lt',
#  'handmaids tale is probably one of the weirdest shows that i have ever watched',
#  'the handmaid s tale has the most emotionally wrenching nine minutes of tv via',
#  'handmaids tale is insane the first ten minutes of season insane',
#  'the handmaids tale is back on hulu and it s good',
#  'who s going to let me use their hulu info for the handmaids tale',
#  'i stay trippen off handmaids tale it s so fucked i couldn t imagine a world like that',
#  'by the time i got all of my cleaning cooking and editing done i m too tired to start handmaids tale tonight',
#  'time to crack a beer and watch an ep of the handmaids tale chillin',
#  'i m so happy the handmaids tale is back',
#  'nem acredito que tem um epis dio novo de the handmaids tale pra assistir',
#  'the handmaids tale is back and the first episode is already freaking me out i love this show but at the same time i cannot handle it',
#  'rt margaret atwood s handmaidstale novel may have been published in but the show s flashbacks to how gilead came to be a',
#  'the symbolism of june hiding out at',
#  'the symbolism of june hiding out at',
#  'so i just found out that hulu is going to put out two episodes every wednesday of the handmaids tale wtf just release it all at one time i would like to binge watch it',
#  'rt the new episodes of the handmaid s tale suggest it should have ended after season',
#  'the handmaids tale came back on today thehandsmaidstale',
#  'everything you need to know before the handmaid s tale season airs tonight urbanlistbne brisbane thehandmaidstale sbs bingewatching underhiseye',
#  'ok i m watching handmaids tale and going to sleep i might end up pacing around the house but i wanna lie down',
#  'ok well right after this i will be dead tweeting episode of handmaids tale watched episode last night i ll do a recap before i start that',
#  'the handmaid s tale season episode photos june',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'handmaids tale but every fertile woman of cleveland gets impregnated by lebron what idk i m really tired but this could work',
#  'so y all just weren t gonna tell nobody handmaids tale was back cool',
#  'should probably finish reading handmaids tale so i can actually binge through the episodes',
#  'the handmaid s tale the handmaid s tale season episodes and the limits of mercy',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'the handmaid s tale arrisca segunda temporada mais pesada que a primeira',
#  'i think handmaids tale is the best thing that s happened to me all year',
#  'watching handmaids tale',
#  'previously on the handmaids tale',
#  'the handmaid s tale is back here s a look at where things might go via',
#  'there are two episodes of handmaids tale handmaidstale season omg iamfree',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'his would be splat all over that damn highway sorry i m tryna get home to the handmaids tale',
#  'really pissed for only releasing episodes of the handmaids tale and now i can t binge watch like i had intended',
#  'i don t understand why this chick is cutting her ear on handmaids tale',
#  'rt everyone should be watching the handmaids tale',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'when you finish a page paper and realize handmaids tale season in is on hulu',
#  'tbh i don t know what disturbs me more while watching handmaids tale the storyline or the fact it takes place in boston',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'yaaaas handmaids tale season just premiered',
#  'the looming tower proves hulu s political dramas are winning the streaming game',
#  'rt the group activated hangings the tearing apart of human beings the forced childbearing and the appropriation of the results',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'handmaids tale episodes amp were great best show out right now',
#  'watching handmaids tale season amp it s dystopian world is making my gut hurt trumpworld votethemout saveourdemocracy',
#  'rt thr cover beyond handmaidstale streamer faces promising yet uncertain future',
#  'rt thr cover beyond handmaidstale streamer faces promising yet uncertain future',
#  'the handmaid s tale behind the scenes of season s most brutal moments so far',
#  'handmaids tale ja estreou meu cu deu uma tremida',
#  'handmaids tale r u fuckin kidding ms',
#  'rt the group activated hangings the tearing apart of human beings the forced childbearing and the appropriation of the results',
#  'eu nunca estive t o decepcionada com a internet uma semana que saiu o ep da segunda temporada de the handmaids tale e simplesmente ainda n o tem legenda to triste',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'rt nerd the handmaid s tale mostra como a fun o biol gica pode ser usada como pretexto para o exerc cio do controle social sob',
#  'meu deeeus essa segunda temporada de the handmaids tale t toooooop caralho essa fruta t muito aben oada',
#  'to baixando handmaids tale meu deus me ajuda',
#  'the handmaids tale is so good but tbh i want this to be the last season because watching it makes me so god damn mad',
#  'meu hoje volta handmaids tale eu vo me morrer todo',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'olhaaaa hoje saiu the handmaids tale',
#  'the handmaid s tale margaret atwood via blogger bookreview',
#  'when you need it',
#  'rt the new episodes of the handmaid s tale suggest it should have ended after season',
#  'holy shit the handmaids tale',
#  'handmaids tale is stressing me tf out',
#  'rt handmaids tale is stressing me tf out',
#  'so stoked for season two of the handmaids tale i accidentally said under his eye to the cashier as i took my reusable tote and went on my way no regrets',
#  'handmaid s tale star max minghella says he has a very cynical view of his gender via',
#  'j temos links da legenda de handmaids tale',
#  'in hindsight starting to watch the handmaids tale while extra emotional after having my baby may not have been the best decision i ve made',
#  'ansiosa pra chegar amanh e assistir the handmaids tale',
#  'okay but me watching the handmaids tale rn',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'the handmaids tale season premiere recap an exercise in self flagellation hot news',
#  'rt doe don t talk to me this weekend bitches the handmaids tale is byke',
#  'thats okay though handmaids tale is out and cr is tomorrow and all is well',
#  'the handmaids tale is back',
#  'saiu the handmaids tale praised be porraaaaaaaaaaaaaaaaaaaa',
#  'rt handmaidstale star max minghella says he has a very cynical view of his gender',
#  'i sit in silence after every episode of the handmaids tale feeling numb and not sure what to do with myself',
#  'season handmaids tale on hulu now',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt man kevin williamson must be watching this handmaids tale season opener like porn',
#  'handmaids tale voltando hoje acho que agora crio coragem pra ver os dois ltimos da primeira temporada',
#  'season of the handmaids tale is our season of the handmaids tale is out ahhhhh',
#  'naw current seasons they come out weekly but handmaids tale and the looming tower are both fucking good',
#  'that opening scene to handmaids tale season omg harrowing then when kate bush started playing i lost it with this show back it s going to be a bleak couple of weeks handmaidstale',
#  'onde assistir the handmaids tale',
#  'handmaids tale time omf',
#  'planning my takeover tomorrow at bad boy book babes and watching the handmaids tale sipping wine in my jammies what could be better check me out tomorrow at pm est let s have some fun',
#  'thank you for episodes of the handmaids tale',
#  'is the handmaids tale good',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'women who support please read this',
#  'someone with hulu date me pronto handmaids tale is back',
#  'british fans vent frustration over the handmaid s tale wait',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'season two of the handmaids tale just got dropped hulu its basically finals week you cant do this to me',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'the only ones i watched straight through were the handmaids tale and harlots',
#  'i liked it more than the handmaids tale',
#  'handmaid s tale star max minghella says he has a very cynical view of his gender',
#  'rt handmaid s tale star max minghella says he has a very cynical view of his gender',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt the handmaid s tale season episode explores emily s gut wrenching back story',
#  'handmaids tale season that s all',
#  'ok new season of the and handmaids tale all in one week i can t',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'i love handmaids tale and the book messed me up so much but the show is just making me mad bc i want to fix it',
#  'saiu handmaids tale blessed be',
#  'there s actually some good shit on hulu but i m hype for handmaids tale too thooo',
#  'there s actually some good shit on hulu but i m hype for handmaids tale too thooo',
#  'there s actually some good shit on hulu but i m hype for handmaids tale too thooo',
#  'handmaids tale is back so i guess i gotta buy a hulu subscription again',
#  'can hulu keep the handmaid s tale momentum going yes as long as cheeto s in the whitehouse this isn t fiction',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt watching the handmaids tale as a bostonian woman is an extra unsettling experience',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'praise be handmaids tale is back bitchesssssssss',
#  'the handmaid s tale une s rie au nom de toutes les femmes',
#  'to engasgada com os primeiros dez minutos de the handmaids tale ate agora caralho',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'it really bothers me that in the handmaids tale they pronounce offred differently than any other name like ofdaniel',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'the handmaids tale finally',
#  'rt watching the handmaids tale also known as mike pence porn on hulu',
#  'rt watching the handmaids tale also known as mike pence porn on hulu',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'rt tonight pm on the handmaids tale returns for season get ready',
#  'handmaids tale j voltou com dedo no cu e gritaria meu deus',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'rt the handmaid s tale behind the scenes of season s most brutal moments so far indie mus',
#  'finally watched the new episode of the handmaids tale and blessed be the fruit ahhhhhh',
#  'why the handmaid s tale is more relevant one year after the first season jessica valenti',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'tentando acompanhar todas informa es dos eps de suits to the handmaids tale mas o sono n o t ajudando',
#  'rt the handmaid s tale behind the scenes of season s most brutal moments so far indie mus',
#  'time to watch season of the handmaids tale been excited to see where the story goes and hope this season s as good as the first',
#  'the handmaids tale seriously has me ready to stay up all night to watch but they only gave us two episodes thehandmaidtale hulu obsessed',
#  'handmaids tale is back today and i m thriving',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'and now i shall watch every episode of handmaids tale twice as i did every episode of ahs cause u always catch things the nd time around',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'so they released two episodes of the handmaids tale i unfortunately wanted to watch the full season tonight',
#  'rt the handmaid s tale behind the scenes of season s most brutal moments so far indie mus',
#  'handmaids tale got a little shades of gray ey on episode just skip to the part where june fucks shit up rescues her daughter and has that awkward exchange w her actual husband and nick pls',
#  'between sexmurder robot cowboys and the handmaids tortureporn tale i am really hoping the next installment of peak tv is a show about intelligent lemurs sitting quietly and reading the style section occasionally they drink herbal tea',
#  'rt between sexmurder robot cowboys and the handmaids tortureporn tale i am really hoping the next installment of peak tv is',
#  'tempted to try handmaids tale again cuz i absorb all tv and media generally like a high blast vacuum but idk if i can put myself through that trauma and brutality hm',
#  'parks watch the handmaids tale',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'nao sei pq demorei tanto pra come ar the handmaids tale pqp que s rie minhas amigas que s rie',
# ...
#  'watched the first ten mins of season two of handmaids tale and i m already angry this show is exhausting',
#  'watching season of the handmaids tale',
#  'rt we live in the reproductive dystopia of the handmaid s tale',
#  'handmaids tale is on don t bother me on wednesday s',
#  'can hulu keep handmaid s tale momentum latestcomments',
#  'this new episode of the handmaids tale jesus christ',
#  'the handmaid s tale is as searing as ever in season but its blind spots haven t gone away',
#  'really wanna watch the new westworld and handmaids tale but i don t have the time',
#  'yo the handmaids tale is wickedy wackkk i love it',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt can hulu keep the handmaid s tale momentum going',
#  'handmaids tale is seriously so fucking good it s scary how unmerciful complete power is',
#  'rt we live in the reproductive dystopia of the handmaid s tale',
#  'courtney and i can t be the only ones who have compared aunt lydia to ms trunchble right the handmaids tale extreme matilda',
#  'i mean handmaids tale is an ok show but have you ever walked around salt lake city utah for like minutes before',
#  'the handmaidstaleseason premiere episodes are somehow more terrifying and awesome than last year handmaidstale thehandmaidstale',
#  'the handmaidstaleseason premiere episodes are somehow more terrifying and awesome than last year handmaidstale thehandmaidstale',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt alexis bledel shines in the riveting second episode of the handmaid s tale s second season',
#  'first episode of handmaids tale season super lit',
#  'ok goodbye world i m watching the handmaids tale',
#  'rt thr cover beyond handmaidstale streamer faces promising yet uncertain future',
#  'rt thr cover beyond handmaidstale streamer faces promising yet uncertain future',
#  'watching the handmaids tale is like eating handfuls of salt idk why i keep doing it',
#  'the handmaid s tale season hbo netflix hulu movies gomovies putlocker fmovies yesmovies watchfree ozee cracker yidio m ufree freemoviesonline watchmoviesonline movies lavamovies gameofthrones westworld',
#  'yikes you are the second person i have seen nearly hurl due to handmaids tale this makes me nervous',
#  'yikes you are the second person i have seen nearly hurl due to handmaids tale this makes me nervous',
#  'alas according to scene was shot at an active canadian newspaper office handmaidstale',
#  'watches handmaids tale once',
#  'watches handmaids tale once',
#  'essa cena inicial de handmaids tale eu to suando frio de nervoso',
#  'whoever scores handmaids tale must have so much fucking fun handmaidstaleseason',
#  'rt the handmaid s tale arrisca segunda temporada mais pesada que a primeira',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'if anyone needs me i will be unavailable every wednesday from now until handmaids tale is over good luck reaching me',
#  'handmaids tale pu eta',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'the handmaid s tale and the suffering of women in entertainment when does empathy become exploitation',
#  'season of the handmaids tale begins with the handmaids in nooses in centerfield of fenway park so wild',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'as a black person uh handmaids tale really didn t have to open like that i need to lay down',
#  'perguntas que queremos respostas na segunda temporada de the handmaid s tale',
#  'rt perguntas que queremos respostas na segunda temporada de the handmaid s tale',
#  'rt can hulu keep the handmaid s tale momentum going',
#  'e agora que voltou handmaids tale e eu preciso dormir mas n o consigo dormir pensando no episodio',
#  'y all the handmaids tale season has me shook',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'the handmaids tale is straight up weird',
#  'why can t i get past the first minuets of the handmaids tale',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'catching up with the handmaids tale you would absolutely love',
#  'there are two episodes of the handmaids tale i was only expecting one blessed be the fruit',
#  'eu n o to em casa e to sem meu computador e eu preciso delo pra assistir the handmaids tale',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'at que enfim eu esbocei algum sorriso vendo te handmaids tale',
#  'rt hulu posted not one but two episodes of season two of the handmaids tale',
#  'handmaids tale got me like praisebe',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt can hulu keep the handmaid s tale momentum going',
#  'wow handmaids tale season out now on hulu im living rn',
#  'rt can hulu keep the handmaid s tale momentum going',
#  'rt ann dowd i think it s a reminder in a wonderful way for people to stay alert stay awake keep thinking on your own and not t',
#  'i m so glad i got into handmaids tale thehandmaidstale',
#  'rt i m so glad i got into handmaids tale thehandmaidstale',
#  'rt como handmaids tale come a com uma cena dessa socorro nao tem minutos ja to aqui serie do milenio',
#  'rt you all are really going to watch the premiere tonight',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'so what did you think handmaidstale handmaidstaleseason resistsister',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt there s beauty in the darkest of places speaks to about bringing the colonies to life https',
#  'rt handmaidstale season manages somehow to feel even more resonant to our current political climate than the first was',
#  'handmaids tale is crazy good handmaidstale',
#  'the handmaids tale is absolutely wild would recommend',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'how much can a woman suffer before she breaks in our metoo moments in our rising up against the current anti woman regime you can watch thehandmaidstale season as an allegory to our current political climate',
#  'rt how much can a woman suffer before she breaks in our metoo moments in our rising up against the current anti woman regime',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'the handmaids tale got me really debating leaving this country lol',
#  'rt egbuziem the handmaids tale got me really debating leaving this country lol',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt the handmaids tale is back blessed be the motherfuckin fruit',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'handmaids tale season handmaids tale season handmaids tale season',
#  'rt season of the handmaid s tale seems likely to test the limits of its characters capacity for forgiveness and for mercy',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt doe don t talk to me this weekend bitches the handmaids tale is byke',
#  'omq handmaids tale season',
#  'que in cio espetacular dessa temporada de handmaids tale bixo eu n o fa o ideia do que vai acontecer j passou da hist ria do livro e o final do epis dio deu possibilidade de qualquer coisa',
#  'lukemann handmaids tale already watched both episodes',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'handmaids tale is gnarly as hell',
#  'kkkkajska a eu amo s ries de conforto tenta assistir westworld the handmaids tale american gods s o boas real',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'rt wrote an incredible profile on for bustle and i just got the chance to read it this piece',
#  'handmaids tale on hulu',
#  'y all the handmaids tale is the craziest shit i have ever scene this opening scene took me tf out',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'the handmaid s tale sigue deprimi ndome v a es',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'handmaids tale is wild omg',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'i gotta watch the new handmaids tale episodes',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'i made a rule for myself i would not include anything that human beings had not already done in some other place or time via',
#  'um handmaids tale',
#  'just when you thought handmaids tale couldn t get any more fucked up they take it there damn',
#  'rt nick from the handmaids tale is my ryan gosling',
#  'rt nick from the handmaids tale is my ryan gosling',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt thehandmaidstale episode recap slay rory gilmore slay via',
#  'rt thehandmaidstale episode recap slay rory gilmore slay via',
#  'i clearly should watch the new episode of handmaids tale before doing homework because then i ll be able to focus better right yes',
#  'veo the handmaids tale y pienso oyyy yo ya hubiese matao a esa vieja pero nicagando podr a hacer las cosas que hace june',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt take the future into your own hands season of the handmaidstale is now streaming new episodes wednesdays only on',
#  'hi yes i worked hours today and even i already finished the two new episodes of the handmaids tale i want more it s so good',
#  'rt can hulu keep the handmaid s tale momentum going',
#  'minutes into the new episode of the handmaids tale and i am balling my eyes out',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'rt it s just a happy accident that the two shows i ve been on have permeated our culture in this way http',
#  'season of handmaids tale already has me so fucked up',
#  'the first episodes of the handmaids tale have me fucked up but it did surprisingly make my day a lot better',
#  'thehandmaidstale season premiere review june and the unwomen via',
#  'ummm the handmaids tale is a fucking mess',
#  'was going to watch the new handmaids tale but today was honestly too much for me so if you need me you know where i ll be',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'rt with the handmaid s tale asks when does empathy cross the line into exploitation',
#  'most of us view the handmaid s tale as a cautionary one but the actions of some political leaders make it seem more prophetic whatimwatching',
#  'the handmaids tale is too real everyone needs to watch it',
#  'you guys don t sleep on this the handmaid s tale season two review a menacing harrowing return',
#  'don t talk to me this weekend bitches the handmaids tale is byke',
#  'rt doe don t talk to me this weekend bitches the handmaids tale is byke',
#  'first two episodes of handmaids tale were beyond',
#  'them playing kate bush the first episode of the handmaids tale they know im watching',
#  'rt can hulu keep the handmaid s tale momentum going',
#  'oi seguimores manda link de torrent do epis dio novo de handmaids tale',
#  'rt the handmaid s tale arrisca segunda temporada mais pesada que a primeira',
#  'being bad with my boyfriend and watching two episodes of the handmaids tale in a row',
#  'handmaids tale is already stressing me out',
#  'the first episode of handmaids tale s has me traumatized forever jfc',
#  'first scene of the handmaids tale from season ep made me almost do the ugly cry handmaidstaleseason my poor heart amazing show praisebehismercy',
#  'rt handmaidstale showrunner tells us how they snagged for season',
#  'rt handmaidstale showrunner tells us how they snagged for season',
#  'rt handmaidstale showrunner tells us how they snagged for season',
#  'don t handmaids tale come back on tonight',
#  'this two at a time handmaids tale is gonna kill me hulu handmadehour handmaidstale',
#  'true life the handmaids tale scares the actual shit out of me but i also cannot stop watching it giving myself voluntary nightmares',
#  'rt i made a rule for myself i would not include anything that human beings had not already done in some other place or time ht',
#  'honestly btwn kanye chance kim and the handmaids tale i can t handle believe we just lived through today',
#  'damn handmaids tale is waaaaack',
#  'gra as a deus pelo recap de the handmaids tale pq eu n o lembrava de nada',
#  'a handmaids tale is truly one of the best shows and i m so happy season is here',
#  'going to try to watch the handmaids tale this is the rd try i can t seem to get into it at all',
#  'nos esperan episodios de mucho dolor',
#  'handmaids tale is back',
#  ...]

# %%
clean_df = pd.DataFrame(clean_tweet,columns=['cleaned_tweet'])

# %%
df_clean = pd.concat([df,clean_df], axis = 1, ignore_index = True)

# %%
df.head()
# Out:
#   Country                                              Tweet City State
# 0     NaN  The Handmaid’s Tale returns today and it’s sti...  NaN   NaN
# 1     NaN  For fans of @HandmaidsOnHulu who are starting ...  NaN   NaN
# 2     NaN  "Con esta temática tan increíble y a la vez ta...  NaN   NaN
# 3     NaN  نقدم لكم ترجمة الحلقة الأولى من الموسم الثاني\...  NaN   NaN
# 4     NaN  نقدم لكم ترجمة الحلقة الأولى من الموسم الثاني\...  NaN   NaN

# %%
df_clean.columns = ['Country','Tweet','City','State','Clean_tweet']

# %%
df_clean.sample(5)
# Out:
#      Country                                              Tweet City State  \
# 5322     NaN  RT @HandmaidsOnHulu: Take the future into your...  NaN   NaN
# 4827     NaN              só queria assistir the handmaids tale  NaN   NaN
# 5699     NaN  Пересматриваю Handmaids Tale, тк вышел второй ...  NaN   NaN
# 7075     NaN  RT @espinof_com: #TheHandmaidsTale todo lo que...  NaN   NaN
# 5896     NaN  entre the handmaids tale y perdona nuestros pe...  NaN   NaN
#
#                                             Clean_tweet
# 5322  rt take the future into your own hands season ...
# 4827               s queria assistir the handmaids tale
# 5699                                     handmaids tale
# 7075  rt com thehandmaidstale todo lo que funciona y...
# 5896  entre the handmaids tale y perdona nuestros pe...

# %% [markdown]
# ## Performing Sentiment Analysis using Text Blob

# %%
for i in range(0,len(df_clean)):
    blob = TextBlob(df_clean.loc[i,"Clean_tweet"])
    df_clean.loc[i,'polarity'] = blob.sentiment.polarity

# %%
df_clean.sample(5)
# Out:
#      Country                                              Tweet    City State  \
# 627      NaN  RT @harpersbazaarus: The Handmaid's Tale Seaso...     NaN   NaN
# 6679     NaN  Samira Wiley of 'The Handmaid's Tale' to Discu...     NaN   NaN
# 7239     NaN  Here's how The Handmaid's Tale created its hel...     NaN   NaN
# 85       NaN  no pude ver mas de los primeros 20 minutos del...     NaN   NaN
# 6115      US  If trump gets impeached and pence becomes pres...  Austin    TX
#
#                                             Clean_tweet  polarity
# 627   rt the handmaid s tale season episode explores...       0.0
# 6679  samira wiley of the handmaid s tale to discuss...       0.0
# 7239  here s how the handmaid s tale created its hel...       0.0
# 85    no pude ver mas de los primeros minutos del nu...       0.0
# 6115  if trump gets impeached and pence becomes pres...       0.0

# %%
for i in range(0,len(df_clean)):
    if(df_clean.loc[i,"polarity"] > 0) :
        df_clean.loc[i,'sentiment'] = 1
    else:
        if(df_clean.loc[i,"polarity"] < 0):
            df_clean.loc[i,'sentiment'] = -1
        else:
            df_clean.loc[i,'sentiment'] = 0

# %%
df_clean.sample(5)
# Out:
#      Country                                              Tweet City State  \
# 2634     NaN  I know it's not Stephen King but I'm looking f...  NaN   NaN
# 7109     NaN  ta feliz the handmaids tale https://t.co/dvzJB...  NaN   NaN
# 4531     NaN  How the Women of The Handmaid’s Tale Do Self-C...  NaN   NaN
# 6309     NaN  Both versions of The Handmaid’s Tale have a pr...  NaN   NaN
# 1012     NaN  RT @sophieGG: On season two of The Handmaid's ...  NaN   NaN
#
#                                             Clean_tweet  polarity  sentiment
# 2634  i know it s not stephen king but i m looking f...  0.116667        1.0
# 7109                        ta feliz the handmaids tale  0.000000        0.0
# 4531  how the women of the handmaid s tale do self c...  0.000000        0.0
# 6309  both versions of the handmaid s tale have a pr...  0.000000        0.0
# 1012  rt on season two of the handmaid s tale in whi...  0.500000        1.0

# %% [markdown]
# ## Sentiment Analysis by Country

# %%
df_clean.nunique()
# Out:
# Country          21
# Tweet          5334
# City            175
# State            64
# Clean_tweet    4507
# polarity        542
# sentiment         3
# dtype: int64

# %%
country_senti = df_clean.groupby(['Country'])['sentiment'].mean()
country_pol = df_clean.groupby(['Country'])['polarity'].mean()

# %%
country_senti.sample(5)
# Out:
# Country
# CA    1.000000
# MX    1.000000
# CN    0.000000
# AU   -0.142857
# IT    0.000000
# Name: sentiment, dtype: float64

# %%
country_pol.sample(5)
# Out:
# Country
# GB    0.057143
# MX    0.250000
# BR    0.005263
# FR    0.000000
# ES   -0.150000
# Name: polarity, dtype: float64

# %%
df_clean.to_csv('handsmaidtail_1senti.csv',sep=',',index=False,encoding='utf-8')

# %% [markdown]
# ## Finding percentage of negative vs positive tweets

# %%
pos_tweets = [ tweet for index, tweet in enumerate(df_clean['Clean_tweet'][df_clean['sentiment'] == 1])]
neu_tweets = [ tweet for index, tweet in enumerate(df_clean['Clean_tweet'][df_clean['sentiment'] == 0])]
neg_tweets = [ tweet for index, tweet in enumerate(df_clean['Clean_tweet'][df_clean['sentiment'] == -1])]

# %%
print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(df_clean['Clean_tweet'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(df_clean['Clean_tweet'])))
print("Percentage of negative tweets: {}%".format(len(neg_tweets)*100/len(df_clean['Clean_tweet'])))
# Out:
# Percentage of positive tweets: 36.27774615822425%
# Percentage of neutral tweets: 47.45589072282299%
# Percentage of negative tweets: 16.26636311895276%

# %% [markdown]
# ## Sentiment Analysis for States in USA

# %%
df_state = df_clean[df_clean.Country == 'US']

# %%
df_state.shape
# Out:
# (183, 7)

# %%
df_state.nunique()
# Out:
# Country          1
# Tweet          167
# City           122
# State           37
# Clean_tweet    163
# polarity        65
# sentiment        3
# dtype: int64

# %%
State_senti = df_state.groupby(['State'])['sentiment'].mean()
State_pol = df_state.groupby(['State'])['polarity'].mean()

# %%
State_senti.sample(5)
# Out:
# State
#  AZ   -0.250000
#  MI    0.250000
#  GA    0.454545
#  OH    0.500000
#  LA    1.000000
# Name: sentiment, dtype: float64

# %%
State_pol.sample(5)
# Out:
# State
#  MD   -0.875000
#  NV   -0.425000
#  DC   -0.063763
#  OR   -0.065404
#  CA    0.062908
# Name: polarity, dtype: float64

# %%
pos_tweets = [ tweet for index, tweet in enumerate(df_state['Clean_tweet'][df_state['sentiment'] == 1])]
neu_tweets = [ tweet for index, tweet in enumerate(df_state['Clean_tweet'][df_state['sentiment'] == 0])]
neg_tweets = [ tweet for index, tweet in enumerate(df_state['Clean_tweet'][df_state['sentiment'] == -1])]

# %%
print("Percentage of positive tweets within US: {}%".format(len(pos_tweets)*100/len(df_state['Clean_tweet'])))
print("Percentage of neutral tweets within US: {}%".format(len(neu_tweets)*100/len(df_state['Clean_tweet'])))
print("Percentage of negative tweets within US: {}%".format(len(neg_tweets)*100/len(df_state['Clean_tweet'])))
# Out:
# Percentage of positive tweets within US: 38.797814207650276%
# Percentage of neutral tweets within US: 39.34426229508197%
# Percentage of negative tweets within US: 21.85792349726776%
